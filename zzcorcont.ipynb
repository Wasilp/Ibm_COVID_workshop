# %%
import pandas as pd
import numpy  as np

#from jupyterthemes import jtplot
#jtplot.style(theme='onedork')

# Selected country to represent continent with "around the same population and pib"
#asia = df[df.geoId.isin(['MYS','KMH','MMR'])]
#latine = df[df.geoId.isin(['PER','COL','ECU'])]

# %%
df = pd.read_excel('./data/COVID-19-geographic-disbtribution-worldwide.xlsx', keep_default_na=False, na_values='')
df.continentExp.unique()
# Out:
# array(['Asia', 'Europe', 'Africa', 'America', 'Oceania', 'Other'],
#       dtype=object)

# %%
df[df['countryterritoryCode'].isna()]
df.countryterritoryCode.unique()
# Out:
# array(['AFG', 'ALB', 'DZA', 'AND', 'AGO', 'AIA', 'ATG', 'ARG', 'ARM',
#        'ABW', 'AUS', 'AUT', 'AZE', 'BHS', 'BHR', 'BGD', 'BRB', 'BLR',
#        'BEL', 'BLZ', 'BEN', 'BMU', 'BTN', 'BOL', 'BES', 'BIH', 'BWA',
#        'BRA', 'VGB', 'BRN', 'BGR', 'BFA', 'BDI', 'KHM', 'CMR', 'CAN',
#        'CPV', nan, 'CYM', 'CAF', 'TCD', 'CHL', 'CHN', 'COL', 'COM', 'COG',
#        'CRI', 'CIV', 'HRV', 'CUB', 'CUW', 'CYP', 'CZE', 'COD', 'DNK',
#        'DJI', 'DMA', 'DOM', 'ECU', 'EGY', 'SLV', 'GNQ', 'ERI', 'EST',
#        'SWZ', 'ETH', 'FLK', 'FRO', 'FJI', 'FIN', 'FRA', 'PYF', 'GAB',
#        'GMB', 'GEO', 'DEU', 'GHA', 'GIB', 'GRC', 'GRL', 'GRD', 'GUM',
#        'GTM', 'GGY', 'GIN', 'GNB', 'GUY', 'HTI', 'VAT', 'HND', 'HUN',
#        'ISL', 'IND', 'IDN', 'IRN', 'IRQ', 'IRL', 'IMN', 'ISR', 'ITA',
#        'JAM', 'JPN', 'JEY', 'JOR', 'KAZ', 'KEN', 'XKX', 'KWT', 'KGZ',
#        'LAO', 'LVA', 'LBN', 'LSO', 'LBR', 'LBY', 'LIE', 'LTU', 'LUX',
#        'MDG', 'MWI', 'MYS', 'MDV', 'MLI', 'MLT', 'MHL', 'MRT', 'MUS',
#        'MEX', 'MDA', 'MCO', 'MNG', 'MNE', 'MSF', 'MAR', 'MOZ', 'MMR',
#        'NAM', 'NPL', 'NLD', 'NCL', 'NZL', 'NIC', 'NER', 'NGA', 'MKD',
#        'MNP', 'NOR', 'OMN', 'PAK', 'PSE', 'PAN', 'PNG', 'PRY', 'PER',
#        'PHL', 'POL', 'PRT', 'PRI', 'QAT', 'ROU', 'RUS', 'RWA', 'KNA',
#        'LCA', 'VCT', 'SMR', 'STP', 'SAU', 'SEN', 'SRB', 'SYC', 'SLE',
#        'SGP', 'SXM', 'SVK', 'SVN', 'SLB', 'SOM', 'ZAF', 'KOR', 'SSD',
#        'ESP', 'LKA', 'SDN', 'SUR', 'SWE', 'CHE', 'SYR', 'CNG1925', 'TJK',
#        'THA', 'TLS', 'TGO', 'TTO', 'TUN', 'TUR', 'TCA', 'UGA', 'UKR',
#        'ARE', 'GBR', 'TZA', 'USA', 'VIR', 'URY', 'UZB', 'VUT', 'VEN',
#        'VNM', 'ESH', 'YEM', 'ZMB', 'ZWE'], dtype=object)

# %%
df_geo = df.dropna(subset=['countryterritoryCode']).pivot(index='dateRep', columns='countryterritoryCode', values=['cases', 'deaths'])
df_geo.columns
# Out:
# MultiIndex([( 'cases', 'ABW'),
#             ( 'cases', 'AFG'),
#             ( 'cases', 'AGO'),
#             ( 'cases', 'AIA'),
#             ( 'cases', 'ALB'),
#             ( 'cases', 'AND'),
#             ( 'cases', 'ARE'),
#             ( 'cases', 'ARG'),
#             ( 'cases', 'ARM'),
#             ( 'cases', 'ATG'),
#             ...
#             ('deaths', 'VEN'),
#             ('deaths', 'VGB'),
#             ('deaths', 'VIR'),
#             ('deaths', 'VNM'),
#             ('deaths', 'VUT'),
#             ('deaths', 'XKX'),
#             ('deaths', 'YEM'),
#             ('deaths', 'ZAF'),
#             ('deaths', 'ZMB'),
#             ('deaths', 'ZWE')],
#            names=[None, 'countryterritoryCode'], length=424)

# %%
asia = df[df.geoId.isin(['MYS','KMH','MMR'])]
latine = df[df.geoId.isin(['PER','COL','ECU'])]

# %%
np.log10(df_geo['deaths'][['MYS','KHM','MMR','PER','COL','ECU']].cumsum()).plot()
# Out:
# <AxesSubplot:xlabel='dateRep'>

# %%
#['Asia', 'Europe', 'Africa', 'America', 'Oceania', 'Other']
df['continentExp'] = df['continentExp'].map( {'Asia': 0, 'Europe': 1, 'Africa': 2,'America':3,'Oceania':4,'Other',5} ).astype(int)
df.head()
